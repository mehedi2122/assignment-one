# %% [markdown]
# <a href="https://colab.research.google.com/github/mehedi2122/assignment-one/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing libraires

# %%
import numpy as np
import cv2
import random
from tqdm import tqdm
import os
import matplotlib.pyplot as plt

# %% [markdown]
# Connecting with drive
